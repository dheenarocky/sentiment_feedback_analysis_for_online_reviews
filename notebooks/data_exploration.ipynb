# %%
import pandas as pd

# Load the cleaned dataset
data = pd.read_csv(r'C:\Dheena Rocky\PROJECTS\sentiment_feedback_analysis_for_online_reviews\data\new_dataset.csv')

# Display the first few rows
data.head()
# Out:
#   Sentiment                                             Review  \
# 0  positive  i wish would have gotten one earlier love it a...
# 1   neutral  i ve learned this lesson again open the packag...
# 2   neutral          it is so slow and lags find better option
# 3   neutral  roller ball stopped working within months of m...
# 4   neutral  i like the color and size but it few days out ...
#
#    cleaned_review_length  review_score
# 0                     19             5
# 1                     88             1
# 2                      9             2
# 3                     12             1
# 4                     21             1

# %%
data.isnull().sum()
# Out:
# Sentiment                0
# Review                   3
# cleaned_review_length    0
# review_score             0
# dtype: int64

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Sentiment                0
# Review                   3
# cleaned_review_length    0
# review_score             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17340 entries, 0 to 17339
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sentiment              17340 non-null  object
#  1   Review                 17337 non-null  object
#  2   cleaned_review_length  17340 non-null  int64
#  3   review_score           17340 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 542.0+ KB

# %%
data.describe()
# Out:
#        cleaned_review_length  review_score
# count           17340.000000  17340.000000
# mean               30.300461      3.649077
# std                35.836540      1.673500
# min                 0.000000      1.000000
# 25%                 9.000000      2.000000
# 50%                20.000000      5.000000
# 75%                38.000000      5.000000
# max               571.000000      5.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Sentiment', data=data, palette='Set2')
plt.show()
# Out:
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_12712\1239411171.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=data, palette='Set2')

# %%
sns.boxplot(x='Sentiment', y='review_score', data=data, palette='Set3')
plt.show()
# Out:
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_12712\225678673.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Sentiment', y='review_score', data=data, palette='Set3')
